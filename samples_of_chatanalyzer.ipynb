# %%
pip install seaborn wordcloud setuptools wheel jieba tqdm pandas matplotlib
# Out:
# ...
#   Using cached jieba-0.42.1.tar.gz (19.2 MB)
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for jieba: filename=jieba-0.42.1-py3-none-any.whl size=19314458 sha256=fa699e7329dbc5540381510fda25d9a26b7aeffef1111b11cbda0a255f4f7c4e
#   Stored in directory: /Users/xia46268/Library/Caches/pip/wheels/08/a1/a3/5c8ac52cc2f5782ffffc34c95c57c8e5ecb3063dc69541ee7c
# Successfully built jieba
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from chatanalyzer.sample_analysis import analyze_sample_data 

analyze_sample_data('sample_data.csv', 'output_sample.csv')
# Out:
# Random State Used: 4031
# Access token loaded from access_token.txt.
# Analyzing Sentiment: 100%|██████████████████████| 30/30 [00:05<00:00,  5.11it/s]
# Saving DataFrame to CSV:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Text           30 non-null     object
#  1   StrTime        30 non-null     datetime64[ns]
#  2   User           30 non-null     object
#  3   MessageType    30 non-null     object
#  4   Sentiment      30 non-null     int64
#  5   Confidence     30 non-null     float64
#  6   Positive_Prob  30 non-null     float64
#  7   Negative_Prob  30 non-null     float64
# dtypes: datetime64[ns](1), float64(3), int64(1), object(3)
# memory usage: 2.0+ KB
# None
# Analysis complete. Results saved to output_sample.csv
#
#     Successfully sampled 30 messages out of 4661 total chat records!
#
# ...

# %%
from chatanalyzer.full_analysis import batch_request_api

batch_request_api('full_data.csv', 'api_output.csv')
# Out:
# Access token loaded from access_token.txt.
# Requesting Sentiment Analysis:   2%|▎            | 1/47 [00:13<10:10, 13.28s/it]
# Batch 1 Completed. Sample Result:
# {'Text': 'md我从来没有', 'StrTime': Timestamp('2021-07-01 03:20:56'), 'User': 'R', 'MessageType': 'text', 'Sentiment': 0, 'Confidence': 0.975566, 'Positive_Prob': 0.0109951, 'Negative_Prob': 0.989005}
# Batch 1 saved to api_output.csv
# Requesting Sentiment Analysis:   4%|▌            | 2/47 [00:26<10:04, 13.43s/it]
# Batch 2 Completed. Sample Result:
# {'Text': '看你吧', 'StrTime': Timestamp('2021-10-13 22:01:50'), 'User': 'Matteo', 'MessageType': 'text', 'Sentiment': 0, 'Confidence': 0.927485, 'Positive_Prob': 0.0326316, 'Negative_Prob': 0.967368}
# Batch 2 saved to api_output.csv
# Requesting Sentiment Analysis:   4%|▌            | 2/47 [00:28<10:37, 14.16s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ...

# %% [markdown]
# This was aborted here due to API count limitations, but details of the analysis can be found in the samples file.

# %%
from chatanalyzer.result_analysis import analyze_saved_results

analyze_saved_results('api_output.csv', 'final_analysis.csv')
# Out:
# Building prefix dict from the default dictionary ...
# ————————————————————
# Chat analysis for R, Matteo:
# Date of the first chat: 2021-07-01
# R said: "md我从来没有"
# Date of the last chat: 2024-11-13
# Matteo said: "去延边找女朋友了"
# The time difference between the first and last chat dates is 1231 days.
# There are 164 days with message records.
# On average, 28.42 messages are exchanged per day.
# The hour with the highest message frequency is 22, with 448 messages, accounting for 9.61%.
# The month with the highest message frequency is 2021-11, with 562 messages, accounting for 12.06%.
# The longest silence lasted 3766.77 hours, broken by R who said: "材料科学硕士留学出来就业怎么样清楚不".
# ————————————————————
# A total of 4661 messages were exchanged, containing 48336 words.
# Matteo sent 2696.0 messages, accounting for 57.84% of total messages.
# Matteo sent 21523.0 words, accounting for 44.53% of total words.
# R sent 1965.0 messages, accounting for 42.16% of total messages.
# ...

# %% [markdown]
# # install the latest version of chatanalyzer
# ```bash
#    !pip install -i https://test.pypi.org/simple/ chatanalyzer
#    ```

# %% [markdown]
# # Now we can run different modes of analysis in terminal
# 1. Analyze a small sample of data:
# ```bash
#    chatanalyzer sample
#    ```
#
# 2.	Request sentiment analysis for the full dataset via API:
#  ```bash
#     chatanalyzer request
# ```
# 3.	Analyze and summarize saved API results:
#  ```bash
#     chatanalyzer analyze
# ```
